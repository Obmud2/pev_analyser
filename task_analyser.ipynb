# %%
# Download all IGC traces for JWGC Tabor

import soaring_spot_dl as ss

competition_url = "/en_gb/junior-world-gliding-championships-2022-tabor-2022"

jwgc22 = ss.SoaringSpotDL(competition_url)
jwgc22.download_traces(select_day = False)
# Out:
# ...
# No trace for CR (45/45)
# ...
# No trace for CR (45/45)
# ...
# No trace for CR (45/45)
# ...
# No trace for CR (26/45)
# ...
# Skip trace 5 (1/45)
# Skip trace 212 (2/45)
# Skip trace IF (3/45)
# Skip trace 18 (4/45)
# Skip trace FT (5/45)
# Skip trace WE (6/45)
# Skip trace MP (7/45)
# Skip trace CB (8/45)
# Skip trace SO (9/45)
# Skip trace SH (10/45)
# Skip trace S (11/45)
# Skip trace BZI (12/45)
# Skip trace VG (13/45)
# Skip trace DK (14/45)
# Skip trace CK (15/45)
# Skip trace VX (16/45)
# Skip trace BV (17/45)
# Skip trace JM (18/45)
# Skip trace WX (19/45)
# Skip trace N8 (20/45)
# ...
# Skip trace BI (22/45)
# Skip trace Y2 (23/45)
# Skip trace SF (24/45)
# Skip trace S4 (25/45)
# Skip trace 8M (26/45)
# Skip trace LE (27/45)
# Skip trace TE (28/45)
# Skip trace CX (29/45)
# Skip trace TI (30/45)
# Skip trace 3G (31/45)
# Skip trace VIS (32/45)
# Skip trace 11 (33/45)
# Skip trace CP (34/45)
# Skip trace BA (35/45)
# Skip trace Aa (36/45)
# Skip trace NW (37/45)
# Skip trace BZ (38/45)
# ...

# %%
# Find and display Pilot Event Start (PEV) data

import pev_data as pev

res = pev.get_pevs("igc/Class CLUB/2022-08-07")
i = pev.print_pevs(res)
# Out:
# Comp No: 8M
# Start Time: 12:23:11
# PEV: 12:10:23 (-0:12:48)
# ---------------------------------
# Comp No: Y2
# Start Time: 12:23:33
# PEV: 12:11:04 (-0:12:29)
# ---------------------------------
# Comp No: DK
# Start Time: 12:26:18
# PEV: 12:15:26 (-0:10:52)
# ---------------------------------
# Comp No: SF
# Start Time: 12:26:19
# PEV: 12:15:36 (-0:10:43)
# ---------------------------------
# Comp No: WX
# Start Time: 12:27:09
# PEV: 12:15:30 (-0:11:39)
# ---------------------------------
# Comp No: 18
# Start Time: 12:47:09
# PEV: 12:36:13 (-0:10:56)
# PEV: 12:36:22 (-0:10:47)
# ---------------------------------
# Comp No: IF
# Start Time: 12:47:17
# PEV: 12:36:22 (-0:10:55)
# ---------------------------------
# Comp No: TI
# Start Time: 12:47:59
# PEV: 12:40:03 (-0:07:56)
# ---------------------------------
# Comp No: CP
# Start Time: 12:48:02
# PEV: 12:40:00 (-0:08:02)
# ---------------------------------
# Comp No: TE
# Start Time: 12:48:08
# PEV: 12:40:03 (-0:08:05)
# ...
